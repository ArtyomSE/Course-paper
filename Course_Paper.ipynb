# %% [markdown]
# # Получение словаря языка Кечуа

# %% [markdown]
# ### 1. Получение названий статей

# %%
import urllib.request as url
from bs4 import BeautifulSoup
import re
import time

# %%
def encode(string, code_dict):
    pattern = re.compile("|".join(map(re.escape, code_dict.keys())))
    return pattern.sub(lambda match: code_dict[match.group(0)], string)

# %%
f = open('drive/MyDrive/Quechua/links.txt', 'r')
links = f.read()
f.close()

qu_wiki_url = 'https://qu.wikipedia.org/w/index.php?title=Sapaq:TukuyPanqakuna&from='
links = encode(links, {qu_wiki_url: '', '\n': ' '})

f = open('drive/MyDrive/Quechua/sections.txt', 'w')
f.write(links)
f.close()

# %%
encoding_dict = {'ñ': '%C3%B1', 'ó': '%C3%B3', 'ø': '%C3%B8', 'á': '%C3%A1',
                 'é': '%C3%A9', 'í': '%C3%AD', 'ž': '%C5%BE', "\'": '%27',
                 '(': '%28', ')': '%29', ',': '%2C', ':': '%3A'}
articles_names = ''

f = open('drive/MyDrive/Quechua/sections.txt', 'r')
sections = encode(f.read(), encoding_dict).split(' ')
f.close()

for section in sections:
    f = url.urlopen(qu_wiki_url + section)
    articles = f.read()
    f.close()

    articles = BeautifulSoup(articles).get_text()
    articles = encode(articles, {**{'\n': '~', ' ': '_'}, **encoding_dict})
    articles = articles.split('~')[273:-40]
    articles[0] = section
    articles_names += ' '.join(articles)

    time.sleep(0.5)

f = open('drive/MyDrive/Quechua/articles_names.txt', 'w')
f.write(articles_names)
f.close()

articles_names = articles_names.split(' ')
print(f'Количество найденных статей: {len(articles_names)}')
# Out:
# Количество найденных статей: 41566

# %% [markdown]
# ### 2. Получение статей

# %%
# !pip install PyPDF2
# !pip install pycryptodome==3.15.0

# %%
import urllib.request as url
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import PyPDF2 as pdf
import os

# %%
def remove_substr(s, start, end):
    i = s.find(start)
    j = s.find(end, i) + len(end)
    s = s[:i] + s[j:]
    return s

# %%
qu_wiki_url = 'https://qu.wikipedia.org/wiki/'
drive_texts_url = 'drive/MyDrive/Quechua/Texts/'

f = open('drive/MyDrive/Quechua/articles_names.txt', 'r')
articles_names = f.read().split(' ')
f.close()

remove_labels = ((' ', 'Wikipediamanta'), ('Katiguriya', 'contenido'),
                 ('\"https', '(Wikipedia, Qhichwa / Quechua)'))

for article_name in articles_names:
    try:
        f = url.urlopen(qu_wiki_url + article_name)
    except (UnicodeEncodeError, HTTPError, FileNotFoundError):
        continue

    text = f.read()
    text = BeautifulSoup(text).get_text()

    for start, end in remove_labels:
        text = remove_substr(text, start, end)

    try:
        f = open(drive_texts_url + article_name + '.txt', 'w')
    except FileNotFoundError:
        article_name = article_name.replace('/', '_')
        f = open(drive_texts_url + article_name + '.txt', 'w')
    f.write(text)
    f.close()

articles_names = os.listdir(drive_texts_url[:-1])
print(f'Количество доступных статей: {len(articles_names)}')
# Out:
# Количество доступных статей: 39981

# %% [markdown]
# ### 3. Добавление pdf-файлов

# %%
# !pip install PyPDF2
# !pip install pycryptodome==3.15.0

# %%
import PyPDF2 as pdf
import os

# %%
pdf_names = ('dialnet', 'dictionary', 'evangelioc', 'manual', 'santa_clara')

drive_texts_url = 'drive/MyDrive/Quechua/Texts/'

for pdf_name in pdf_names:
    pdf_file = open(f'drive/MyDrive/Quechua/PDF/{pdf_name}.pdf', 'rb')
    pdf_reader = pdf.PdfReader(pdf_file)

    pages_num = len(pdf_reader.pages)
    print(f'"{pdf_name}" has {pages_num} pages')

    txt_file = open(drive_texts_url + pdf_name + '.txt', 'a')
    for page_num in range(pages_num):
        text = pdf_reader.pages[page_num].extract_text()
        txt_file.write(text)
    txt_file.close()

    pdf_file.close()

texts_names = os.listdir(drive_texts_url[:-1])
print(f'\nКоличество доступных текстов: {len(texts_names)}')
# Out:
# "dialnet" has 15 pages
# "dictionary" has 1443 pages
# "evangelioc" has 402 pages
# "manual" has 133 pages
# "santa_clara" has 76 pages
#
# Количество доступных текстов: 39986

# %% [markdown]
# ### 4. Очистка и лемматизация текстов

# %%
import os

# %%
def replace_symbols(symbols, replacement, text):
    for symbol in symbols:
        text = text.replace(symbol, replacement)
    return text

def clean_text(text):
    # Lowering case:
    text = text.lower()

    # Removing punctuation and other extra symbols:
    text = replace_symbols(',.[]{}()=≈>≥<≤+‡-±−*&^%$#@¡"!~;:ː§/\|¿?«»•·ºª↑↓←→≠Ø½∞', '', text)
    text = text.replace('\xa0', '')
    text = text.replace('www', '')Г

    # Replacing newline symbols with spaces:
    text = text.replace('\n', ' ')
    for _ in range(5):
        text = text.replace('  ', ' ')
    if text[0] == ' ':
        text = text[1:]
    if text[-1] == ' ':
        text = text[:-1]

    # Replacing all numbers with masks:
    text = replace_symbols('0123456789', 'NUM', text)

    return text

def replace_morphemes(text, morphemes, marker, first_layer=False):
    if first_layer:
        for morpheme in morphemes:
            text = text.replace(morpheme + ' ', marker + ' ')
    else:
        for morpheme in morphemes:
            text = text.replace(morpheme + marker, marker)
    return text

def lemmatize_text(text):
    ###  Numerals  ###
    numeral_token = 'NUM'

    tens = ('chunka', 'pachak', 'waranqa', 'hunu') # 10, 100, 1000, 1000000
    for ten in tens:
        text = text.replace(ten + ' ', numeral_token + ' ')

    figures = ('chusaq', 'huk', 'iskay', 'kimsa', 'tawa', 'pichqa', 'suqta', 'qanchis', 'pusaq', 'isqun') # 0-9
    for figure in figures:
        text = text.replace(' ' + figure + ' ', ' ' + numeral_token + ' ')
        text = text.replace(figure + numeral_token, numeral_token)

    quantitative_suffixes = ('niyuq', 'yuq')
    for quantitative_suffix in quantitative_suffixes:
        for figure in figures:
            text = text.replace(figure + quantitative_suffix, numeral_token)

    ordinal_suffixes = ('ñaqin', 'ñiqin', 'kaq')
    for  ordinal_suffix in ordinal_suffixes:
        text = text.replace(' ' +  ordinal_suffix + ' ', ' ')

    ###   Verbs   ###
    infinitive_ending = 'y'
    marker = '~'

    # Interrogative to affirmative:
    interrogative_suffix = 'chu'
    text = text.replace(interrogative_suffix + ' ', ' ')

    # Conjunctive:
    simple_endings = ('yman', 'waq', 'nkiman', 'sunman', 'nman', 'sunchikman', 'chwan',
                      'nchikman', 'ykuman', 'waqchik', 'nkichikman', 'nkuman')
    complex_endings = ('yki', 'ykichik', 'ykiku', 'wanki', 'wankiku', # 'wan', <- not to mix
                       'wanchik', 'wanku', 'sunki', 'sunkichik', 'sunkiku')
    text = replace_morphemes(text, simple_endings + complex_endings, marker, True)

    ### --------- ###

    ###   Nouns   ###
    # All cases to nominative:
    cases_endings = ('p', 'pa', 'paq', 'manta', 'wan', 'ta', 'pi', 'kama', 'rayku', 'man', 'hina', 'pura')
    text = replace_morphemes(text, cases_endings, '', True)
    # Plural to singular:
    text = text.replace('kuna ', ' ')

    ### --------- ###

    # Indicative:
    future_endings = ('saq', 'nki', 'nqa', 'sun', 'sunchik', 'saqku', 'nkichik', 'nqaku')
    present_endings = ('ni', 'nki', 'n', 'nchik', 'yku', 'nkichik', 'nku')
    text = replace_morphemes(text, future_endings + present_endings, marker, True)

    past_narrative_continuous_suffixes = ('rqa', 'ra', 'sqa', 'chka')
    text = replace_morphemes(text, past_narrative_continuous_suffixes, marker)

    complex_suffix = 'q'
    text = text.replace(complex_suffix + ' ka' + marker + ' ', marker + ' ')
    text = text.replace(complex_suffix + ' ', marker + ' ')
    text = text.replace(complex_suffix + 'ku ', marker + ' ')

    # Imperative:
    ending = 'ychik'
    text = text.replace(ending + ' ', marker)

    # Verbs to infinitive:
    text = text.replace(marker, infinitive_ending)

    return text

# %%
drive_texts_url = 'drive/MyDrive/Quechua/Texts/'
drive_processed_texts_url = 'drive/MyDrive/Quechua/Processed_Texts/'

texts_names = os.listdir(drive_texts_url[:-1])
texts_names.sort()

for text_name in texts_names:
    f = open(drive_texts_url + text_name, 'r')
    text = f.read()
    f.close()

    text = clean_text(text)
    text = lemmatize_text(text)

    f = open(drive_processed_texts_url + text_name, 'w')
    f.write(text)
    f.close()

# %% [markdown]
# ### 5. Сборка корпуса Кечуа

# %%
import os

# %%
drive_processed_texts_url = 'drive/MyDrive/Quechua/Processed_Texts/'

texts_names = os.listdir(drive_processed_texts_url[:-1])
texts_names.sort()

f_corpus = open('' + 'drive/MyDrive/Quechua/quechua_corpus.txt', 'w')

for text_name in texts_names:
    f_text = open(drive_processed_texts_url + text_name, 'r')
    text = f_text.read()
    f_corpus.write(text + '\n')
    f_text.close()

f_corpus.close()
print(f'В состав корпуса языка Кечуа вошло {len(texts_names)} текстов')
# Out:
# В состав корпуса языка Кечуа вошло 39986 текстов

# %% [markdown]
# ### 6. Создание TF_IDF матрицы

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def create_tf_idf_matrix(corpus_path, min_df=1, use_idf=True):
    '''
    corpus_path - path to a corpus, where one line - one text

    min_df - the minimum times (or fraction of the texts) a word must occur in the corpus

    use_idf - flag of the usage of idf
    '''
    with open(corpus_path, 'r') as corpus_file:
        vectorizer = TfidfVectorizer(analyzer='word', min_df=min_df, use_idf=use_idf)
        data_vectorized = vectorizer.fit_transform(corpus_file)
    return data_vectorized, vectorizer.get_feature_names_out()

# %%
drive_quechua_url = 'drive/MyDrive/Quechua/'

W, words_list = create_tf_idf_matrix('drive/MyDrive/Quechua/quechua_corpus.txt')

# Saving the TF-IDF matrix:
f = open(drive_quechua_url + 'Matrices/' + 'tf_idf.npy', 'wb')
np.save(f, W)
f.close()

# Saving the words list:
f = open(drive_quechua_url + 'quechua_words_list.txt', 'w')
f.write(' '.join(words_list))
f.close()

print(f'Размерность матрицы W: {W.shape[0]} x {W.shape[1]} (количество текстов x количество слов)\n')
print(f'Некоторые слова из полученного списка слов: {words_list[1000:1005]}')
# Out:
# Размерность матрицы W: 39986 x 325662 (количество текстов x количество слов)
#
# Некоторые слова из полученного списка слов: ['abrirle' 'abrirme' 'abrirse' 'abrirá' 'abrirás']

# %% [markdown]
# ### 7. SVD

# %%
from scipy.sparse.linalg import svds
import numpy as np

# %%
def apply_svd(W, k, output_folder):
    '''
    W - TF-IDF matrix
    k - the rank of the SVD (must be less than any dimension of W)
    '''
    # Apply the SVD function
    u, sigma, vt = svds(W, k)

    # Sorting singular values in descending order as function doesn't garantee it
    descending_order_of_inds = np.flip(np.argsort(sigma))
    u = u[:,descending_order_of_inds]
    vt = vt[descending_order_of_inds]
    sigma = sigma[descending_order_of_inds]

    # Checking that sizes are correct
    assert sigma.shape == (k,)
    assert vt.shape == (k, W.shape[1])
    assert u.shape == (W.shape[0], k)

    # Save the matrixes in folder (just in case)
    matrices_names = ('_sigma_vt.npy', '_sigma.npy', '_u.npy', '_vt.npy')
    matrices = (np.dot(np.diag(sigma), vt).T, sigma, u, vt)

    for matrix_name, matrix in zip(matrices_names, matrices):
        with open(output_folder + str(k) + matrix_name, 'wb') as f:
            np.save(f, matrix)

    return np.dot(np.diag(sigma), vt).T

# %%
drive_matrices_url = 'drive/MyDrive/Quechua/Matrices/'

vv = apply_svd(W, 2, drive_matrices_url)
print(f'Размерность матрицы vv: {vv.shape[0]} x {vv.shape[1]} (количество слов x ранг k)')
# Out:
# Размерность матрицы vv: 325662 x 2 (количество слов x ранг k)

# %% [markdown]
# ### 8. Создание словаря

# %%
def create_dictionary(words_list, vv, output_file):
  dictionary = {}
  for word, vector in zip(words_list, vv):
    dictionary[word] = vector
  np.save(output_file, dictionary)
  return dictionary

# %%
drive_quechua_url = 'drive/MyDrive/Quechua/'

dictionary = create_dictionary(words_list[71:], vv[71:, :], drive_quechua_url + 'quechua_dictionary.npy')

# %%
dictionary
# Out:
# {'aakllana': array([-1.18716188e-04, -8.62949144e-05]),
#  'aakra': array([-1.73732634e-05, -1.67462128e-05]),
#  'aalaw': array([-0.0010711 ,  0.00013546]),
#  'aalborg': array([-0.00115063, -0.00090494]),
#  'aaleniay': array([-1.10437301e-04, -6.70805070e-05]),
#  'aalsmeer': array([-0.00045763, -0.00022895]),
#  'aalst': array([-0.00077081, -0.00060384]),
#  'aaltey': array([-2.52863249e-04, -9.74170206e-05]),
#  'aalto': array([-0.00030796, -0.00027618]),
#  'aaltsapayaanay': array([-0.00024406, -0.00014917]),
#  'aalwaris': array([-0.00033088, -0.00022124]),
#  'aamet': array([-0.00037406, -0.0002669 ]),
#  'aamir': array([-0.00158511, -0.00137535]),
#  'aamor': array([-0.00042757, -0.00031509]),
#  'aanchal': array([-1.73732634e-05, -1.67462128e-05]),
#  'aandhi': array([-1.73732634e-05, -1.67462128e-05]),
#  'aandsliv': array([-0.0001111 , -0.00010218]),
#  'aanhil': array([-1.44761674e-05, -9.72229877e-06]),
#  'aannouncer': array([-0.0001744, -0.0001487]),
#  'aano': array([-0.001089  , -0.00076757]),
#  'aanum': array([-0.00037441, -0.00019975]),
#  'aanumcdot': array([-0.00027054, -0.00017563]),
#  'aanumnumnumnumque': array([-1.42137353e-04, -6.76114068e-05]),
#  'aapke': array([-2.91067587e-05, -2.44302979e-05]),
#  'aapo': array([-1.18218119e-04, -8.91872359e-05]),
#  'aaraaf': array([-0.00037613, -0.00032186]),
#  'aarau': array([-0.00062911, -0.00047473]),
#  'aarchnumnum': array([-8.50753919e-05, -4.98857816e-05]),
#  'aargau': array([-0.00108958, -0.00076925]),
#  'aarhus': array([-0.0010755 , -0.00072571]),
#  'aarkiy': array([-4.4506195e-06, -5.2277417e-06]),
#  'aaronriddhi': array([-6.33989569e-05, -4.63687585e-05]),
#  'aaroy': array([-0.00389928, -0.00310862]),
#  'aartei': array([-0.00021944, -0.00019207]),
#  'aarti': array([-0.00012373, -0.00011575]),
#  'aaruy': array([-3.98935161e-06, -7.10398883e-07]),
#  'aaróy': array([-0.00335887, -0.00263908]),
#  'aas': array([-0.00179526, -0.00066431]),
#  'aash': array([-0.00154708, -0.00087491]),
#  'aashirwad': array([-1.73732634e-05, -1.67462128e-05]),
#  'aashiy': array([-2.91067587e-05, -2.44302979e-05]),
#  'aashí': array([-1.61745163e-05,  8.62924122e-06]),
#  'aattetur': array([-1.76293348e-05, -1.18138318e-05]),
#  'aau': array([-0.00084633, -0.00051425]),
#  'aavv': array([-1.83713903e-07, -7.26586961e-08]),
#  'aay': array([-0.00511614, -0.00119187]),
#  'aaə': array([-9.68080752e-05, -5.42184154e-05]),
#  'ab': array([-0.00664796, -0.00474921]),
#  'aba': array([-7.82231473e-04, -8.71379388e-05]),
#  'ababa': array([-0.0043741 , -0.00330703]),
#  'ababapa': array([-1.18218119e-04, -8.91872359e-05]),
#  'ababaregióy': array([-0.00103762, -0.00074545]),
#  'ababiy': array([-2.93470276e-05, -2.35068783e-05]),
#  'ababol': array([-6.12379677e-08, -2.42195654e-08]),
#  'abacero': array([-6.12379677e-08, -2.42195654e-08]),
#  'abacería': array([-0.00016934, -0.00013559]),
#  'abacial': array([-1.83713903e-07, -7.26586961e-08]),
#  'abaco': array([-0.00259325, -0.0015839 ]),
#  'abad': array([-0.10837493, -0.06390208]),
#  'abada': array([-1.09993023e-04, -9.45866495e-05]),
#  'abaday': array([-0.0016125 , -0.00145751]),
#  'abaddóy': array([-0.00021474, -0.00015931]),
#  'abadejo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abadejonum': array([-1.22475935e-07, -4.84391307e-08]),
#  'abadengo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abadesa': array([-0.00050483, -0.00026973]),
#  'abadesas': array([-3.54782982e-04, -8.51899922e-05]),
#  'abadia': array([-0.00101253, -0.00053209]),
#  'abadisa': array([-1.39090150e-04, -9.46452706e-05]),
#  'abadmantam': array([-0.00039429, -0.00024877]),
#  'abadnumnumnumnum': array([-0.00112768, -0.00065151]),
#  'abadya': array([-0.00020478, -0.00014529]),
#  'abadía': array([-0.00267358, -0.00219307]),
#  'abadías': array([-1.83765686e-04, -6.20143391e-05]),
#  'abaetetuba': array([-0.00024251, -0.00015215]),
#  'abajadero': array([-6.12379677e-08, -2.42195654e-08]),
#  'abajamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abajar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abajeña': array([-6.12379677e-08, -2.42195654e-08]),
#  'abajino': array([-6.12379677e-08, -2.42195654e-08]),
#  'abajo': array([-0.00487497, -0.00298632]),
#  'abajonumnumnum': array([-6.12379677e-08, -2.42195654e-08]),
#  'abakada': array([-0.00031588, -0.00029706]),
#  'abakuk': array([-3.98935161e-06, -7.10398883e-07]),
#  'abal': array([-0.0009041 , -0.00078399]),
#  'abalakiy': array([-0.00059096, -0.0004099 ]),
#  'abalanzar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abalanzarse': array([-1.83713903e-07, -7.26586961e-08]),
#  'abalaustrado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaleador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaleadura': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaleaduras': array([-6.12379677e-08, -2.42195654e-08]),
#  'abalear': array([-1.22475935e-07, -4.84391307e-08]),
#  'abalearnum': array([-1.22475935e-07, -4.84391307e-08]),
#  'abaleo': array([-1.22475935e-07, -4.84391307e-08]),
#  'abaliget': array([-2.79816852e-05, -1.46086945e-05]),
#  'abalizamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abalizar': array([-6.12379677e-08, -2.42195654e-08]),
#  'aballar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abalorio': array([-1.22475935e-07, -4.84391307e-08]),
#  'abalorios': array([-0.00025226, -0.00018879]),
#  'abalu': array([-1.22475935e-07, -4.84391307e-08]),
#  'abaluwu': array([-6.12379677e-08, -2.42195654e-08]),
#  'abalóy': array([-1.22475935e-07, -4.84391307e-08]),
#  'abalúy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abambo': array([-5.79435458e-05, -4.47623649e-05]),
#  'abana': array([-0.00026775, -0.00010851]),
#  'abancalar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abancalare': array([-6.12379677e-08, -2.42195654e-08]),
#  'abancay': array([-0.00849723, -0.00536195]),
#  'abancroft': array([-4.4506195e-06, -5.2277417e-06]),
#  'abanderado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abanderamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abanderar': array([-1.83713903e-07, -7.26586961e-08]),
#  'abanderizar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abando': array([-0.00031968, -0.00012826]),
#  'abandonada': array([-0.00318319,  0.00571249]),
#  'abandonadaqunqasqa': array([-7.53559315e-06, -5.10437393e-06]),
#  'abandonadas': array([-0.00046389, -0.00036739]),
#  'abandonado': array([-0.00032084, -0.0002453 ]),
#  'abandonados': array([-6.12379677e-08, -2.42195654e-08]),
#  'abandonadosaqiysaqisqa': array([-7.53559315e-06, -5.10437393e-06]),
#  'abandonando': array([-3.72954851e-06, -3.75143804e-06]),
#  'abandonar': array([-2.22967280e-05, -1.49535298e-05]),
#  'abandonarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abandonarte': array([-3.81236135e-06, -3.87211475e-06]),
#  'abandoned': array([-0.00018955, -0.0001787 ]),
#  'abandones': array([-0.00013482, -0.00011481]),
#  'abandonis': array([-1.22475935e-07, -4.84391307e-08]),
#  'abandonismo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abandonné': array([-0.00017452, -0.0001358 ]),
#  'abandonnée': array([-9.48238831e-05, -6.54713622e-05]),
#  'abandonnés': array([-3.70758172e-05, -2.92392194e-05]),
#  'abandono': array([-0.00079194, -0.00047645]),
#  'abandons': array([-1.32293670e-04, -8.78697465e-05]),
#  'abandonó': array([-0.00080953, -0.00042845]),
#  'abandoy': array([-0.00011579, -0.00010156]),
#  'abane': array([-0.00110422, -0.00090806]),
#  'abangares': array([-1.1487640e-04, -3.2041981e-05]),
#  'abanibi': array([-0.00012126, -0.00010232]),
#  'abanicar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abanicarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abanicazo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abanico': array([-0.00180766, -0.00117305]),
#  'abaniku': array([-4.28665774e-07, -1.69536958e-07]),
#  'abaniqueo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaniquero': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaniquería': array([-6.12379677e-08, -2.42195654e-08]),
#  'abankay': array([-0.00114565, -0.00071445]),
#  'abanto': array([-0.00753724, -0.0049233 ]),
#  'abanumnumnum': array([-6.12379677e-08, -2.42195654e-08]),
#  'abapo': array([-0.00190386,  0.0006376 ]),
#  'abar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abaratamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaratar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarca': array([-0.00532366, -0.00324723]),
#  'abarcable': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarcado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarcadonumnumnumnumnum': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarcadu': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarcadura': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarcamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarcar': array([-5.51141709e-07, -2.17976088e-07]),
#  'abarcas': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarcay': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarco': array([-1.27104385e-04, -9.46211652e-05]),
#  'abaritonado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarloar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaroa': array([-0.3148669 ,  0.26798008]),
#  'abaroamantam': array([-0.00041149, -0.00012751]),
#  'abarquero': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarques': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarquillado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarquillando': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarquillarse': array([-1.83713903e-07, -7.26586961e-08]),
#  'abarra': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarragamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarraganarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrajado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrajamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrajarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrancadero': array([-1.83713903e-07, -7.26586961e-08]),
#  'abarrancado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrancamiento': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarrancar': array([-1.83713903e-07, -7.26586961e-08]),
#  'abarrancarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarre': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarrer': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarrotar': array([-1.83713903e-07, -7.26586961e-08]),
#  'abarrotarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrote': array([-1.83713903e-07, -7.26586961e-08]),
#  'abarrotero': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrotería': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarrotes': array([-1.83713903e-07, -7.26586961e-08]),
#  'abarru': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrutiriya': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarrutis': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarrutisniyuqmi': array([-6.12379677e-08, -2.42195654e-08]),
#  'abarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abarth': array([-9.56498450e-05, -7.11011144e-05]),
#  'abas': array([-0.00094884, -0.00066194]),
#  'abascal': array([-0.00274694, -0.00185716]),
#  'abashidze': array([-0.00032691, -0.00029021]),
#  'abasraju': array([-0.00345926, -0.00214936]),
#  'abastardar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abastece': array([-1.22475935e-07, -4.84391307e-08]),
#  'abastecedor': array([-6.12379677e-08, -2.42195654e-08]),
#  'abastecer': array([-1.22475935e-07, -4.84391307e-08]),
#  'abastecerme': array([-6.12379677e-08, -2.42195654e-08]),
#  'abastecimiento': array([-1.22475935e-07, -4.84391307e-08]),
#  'abastero': array([-6.12379677e-08, -2.42195654e-08]),
#  'abasto': array([-4.28665774e-07, -1.69536958e-07]),
#  'abastoflor': array([-0.00617613,  0.00416558]),
#  'abastos': array([-6.12379677e-08, -2.42195654e-08]),
#  'abasár': array([-6.98603428e-05, -4.62714676e-05]),
#  'abatana': array([-6.12379677e-08, -2.42195654e-08]),
#  'abatanada': array([-6.12379677e-08, -2.42195654e-08]),
#  'abatanado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abatanar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abate': array([-0.00011301, -0.00010744]),
#  'abati': array([-5.54393893e-05, -6.43588491e-05]),
#  'abatible': array([-6.12379677e-08, -2.42195654e-08]),
#  'abatidero': array([-1.22475935e-07, -4.84391307e-08]),
#  'abatido': array([-5.51141709e-07, -2.17976088e-07]),
#  'abatillo': array([-0.00057527, -0.00028455]),
#  'abatimiento': array([-4.89903741e-07, -1.93756523e-07]),
#  'abatino': array([-0.00013261, -0.00011324]),
#  'abatir': array([-3.06189838e-07, -1.21097827e-07]),
#  'abatirse': array([-2.44951871e-07, -9.68782615e-08]),
#  'abattoirs': array([-0.00016087, -0.00010559]),
#  'abattre': array([-6.86660275e-05, -3.79680966e-05]),
#  'abatí': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaxter': array([-4.4506195e-06, -5.2277417e-06]),
#  'abay': array([-6.12379677e-08, -2.42195654e-08]),
#  'abayado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abayubá': array([-2.59226673e-04, -3.33005280e-05]),
#  'abaza': array([-0.00026227, -0.00020739]),
#  'abazović': array([-0.00180064, -0.00084576]),
#  'abazóy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abaí': array([-0.00076718, -0.00042819]),
#  'abañiy': array([-0.00028702, -0.00013925]),
#  'abañíy': array([-0.00028702, -0.00013925]),
#  'abba': array([-0.00235675, -0.00190318]),
#  'abbadia': array([-3.02596490e-04, -8.07574046e-05]),
#  'abbado': array([-0.00011796, -0.00010477]),
#  'abbas': array([-0.00214135, -0.00149202]),
#  'abbasgulu': array([-0.00024346, -0.00016947]),
#  'abbasi': array([-0.00059414, -0.00045003]),
#  'abbassamento': array([-1.53718186e-05, -9.99059354e-06]),
#  'abbasso': array([-4.91327787e-06, -3.70457186e-06]),
#  'abbate': array([-0.00020297, -0.00020782]),
#  'abbaye': array([-0.00013323, -0.00013011]),
#  'abbemuseum': array([-0.00016087, -0.00010559]),
#  'abbes': array([-0.00063075, -0.00024839]),
#  'abbey': array([-0.00471122, -0.0030188 ]),
#  'abbildung': array([-0.00029773, -0.00023617]),
#  'abbildungey': array([-0.00072394, -0.00069587]),
#  'abbot': array([-0.00028449, -0.00017926]),
#  'abbotsbury': array([-0.00047576, -0.00031344]),
#  'abbotsford': array([-0.00057586, -0.00036688]),
#  'abbott': array([-0.00346286, -0.00220477]),
#  'abbottchuriy': array([-0.0002468 , -0.00020585]),
#  'abbottii': array([-2.55830151e-06, -2.21522639e-06]),
#  'abbottwarmi': array([-0.0002096 , -0.00018656]),
#  'abboud': array([-0.0014207 , -0.00124778]),
#  'abbr': array([-3.13562871e-05, -2.56271217e-05]),
#  'abbrevia': array([-0.00110284, -0.00108967]),
#  'abbreviatahardy': array([-0.00036761, -0.00036322]),
#  'abbreviated': array([-0.00108073, -0.0005351 ]),
#  'abbreviatum': array([-1.92173795e-05, -1.68226640e-05]),
#  'abbruch': array([-0.00020891, -0.00016252]),
#  'abbuffa': array([-4.19474330e-06, -3.79901215e-06]),
#  'abby': array([-0.00061873, -0.0005135 ]),
#  'abbès': array([-0.00022745, -0.00020994]),
#  'abbé': array([-0.00043375, -0.0003279 ]),
#  'abc': array([-0.00486781, -0.00363451]),
#  'abcclio': array([-0.00060186, -0.00012279]),
#  'abcd': array([-0.00072397, -0.00054955]),
#  'abces': array([-0.00023514, -0.00018626]),
#  'abceso': array([-0.00021139, -0.00012338]),
#  'abch': array([-0.00082997,  0.00041674]),
#  'abchasiey': array([-0.0034744, -0.0026573]),
#  'abciy': array([-6.82485260e-06, -5.70716871e-06]),
#  'abcnum': array([-0.00109361, -0.00071084]),
#  'abcnumr': array([-0.00054681, -0.00035542]),
#  'abd': array([-0.00673325, -0.00245808]),
#  'abdagić': array([-0.00030775, -0.00024418]),
#  'abdala': array([-0.00038697, -0.00019597]),
#  'abdali': array([-0.00032904, -0.00023152]),
#  'abdalla': array([-0.00026227, -0.00020739]),
#  'abdallah': array([-0.00053525, -0.00045161]),
#  'abdallahi': array([-0.00021031, -0.00018579]),
#  'abdalá': array([-0.00051634, -0.00041242]),
#  'abde': array([-0.00082997,  0.00041674]),
#  'abdel': array([-0.01149241, -0.00681945]),
#  'abdelaziz': array([-0.00233852, -0.00169512]),
#  'abdelfattahmi': array([-1.37734347e-04, -8.10159003e-05]),
#  'abdelkader': array([-0.00048001, -0.0002843 ]),
#  'abdelkrim': array([-6.96297168e-05, -4.77060741e-05]),
#  'abdelkébir': array([-0.00013113, -0.00010369]),
#  'abdella': array([-0.00095226, -0.00057627]),
#  'abdellatif': array([-0.00013113, -0.00010369]),
#  'abdelmadjid': array([-0.00092972, -0.00080588]),
#  'abdelmalek': array([-0.00018021, -0.00016024]),
#  'abderramáy': array([-0.00057238, -0.0002439 ]),
#  'abderus': array([-0.00134352, -0.00029491]),
#  'abderussturm': array([-0.00026449, -0.00015398]),
#  'abdessalam': array([-9.35030219e-05, -7.86245485e-05]),
#  'abdi': array([-4.95451934e-05, -4.27171896e-05]),
#  'abdicacióy': array([-0.00036386, -0.00028253]),
#  'abdicar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abdicará': array([-6.12379677e-08, -2.42195654e-08]),
#  'abdicati': array([-6.12379677e-08, -2.42195654e-08]),
#  'abdicatioy': array([-3.67120029e-05, -2.54164267e-05]),
#  'abdicó': array([-6.12379677e-08, -2.42195654e-08]),
#  'abdiel': array([-0.00099097, -0.00080416]),
#  'abdilatif': array([-0.00013113, -0.00010369]),
#  'abdirah': array([-0.00013965, -0.00012817]),
#  'abdirashid': array([-0.00122597, -0.00102665]),
#  'abdiso': array([-0.00088893, -0.00069857]),
#  'abdiyas': array([-0.00351765, -0.00159048]),
#  'abdo': array([-0.00068106, -0.00050033]),
#  'abdoangus': array([-0.00379706, -0.00377934]),
#  'abdoangustadrew': array([-0.0003818 , -0.00037755]),
#  'abdoangustawalker': array([-0.00093643, -0.00093438]),
#  'abdoaurantiaca': array([-0.00110513, -0.00109232]),
#  'abdoaurantiacadrew': array([-0.00036838, -0.00036411]),
#  'abdofusca': array([-0.00110513, -0.00109232]),
#  'abdofuscatadrew': array([-0.00036838, -0.00036411]),
#  'abdol': array([-0.00045781, -0.0003678 ]),
#  'abdolhosseiy': array([-2.70374104e-05, -2.32098507e-05]),
#  'abdolkarim': array([-2.70374104e-05, -2.32098507e-05]),
#  'abdolonginqua': array([-0.00110513, -0.00109232]),
#  'abdolonginquadrew': array([-0.00036838, -0.00036411]),
#  'abdomey': array([-0.00093306,  0.00031022]),
#  'abdominal': array([-0.00011951, -0.00011941]),
#  'abdominalnum': array([-0.00018492, -0.0001292 ]),
#  'abdomininigra': array([-0.00110513, -0.00109232]),
#  'abdomininigradrew': array([-0.00036838, -0.00036411]),
#  'abdonigella': array([-0.00110513, -0.00109232]),
#  'abdonigelladrew': array([-0.00036838, -0.00036411]),
#  'abdopallescens': array([-0.00110513, -0.00109232]),
#  'abdopallescensdrew': array([-0.00036838, -0.00036411]),
#  'abdou': array([-0.00197455, -0.00153448]),
#  'abdoul': array([-0.00021802, -0.00018542]),
#  'abdoulaye': array([-0.00213622, -0.00141574]),
#  'abdoy': array([-0.00168241, -0.00099801]),
#  'abdu': array([-2.70374104e-05, -2.32098507e-05]),
#  'abduc': array([-1.22475935e-07, -4.84391307e-08]),
#  'abduccióy': array([-1.83713903e-07, -7.26586961e-08]),
#  'abducir': array([-6.12379677e-08, -2.42195654e-08]),
#  'abductor': array([-6.12379677e-08, -2.42195654e-08]),
#  'abduganíevich': array([-0.00022385, -0.00019428]),
#  'abdugʻaníyevich': array([-0.00022385, -0.00019428]),
#  'abdul': array([-0.00485795, -0.00388473]),
#  'abdulah': array([-0.00125642, -0.00084645]),
#  'abdulaziz': array([-0.00804178, -0.00547361]),
#  'abdulhakim': array([-5.67386045e-05, -4.94806565e-05]),
#  'abduljabbar': array([-0.00073039, -0.00056578]),
#  'abdulla': array([-0.00024346, -0.00016947]),
#  'abdullah': array([-0.00863273, -0.00605676]),
#  'abdullahi': array([-0.00068177, -0.00043418]),
#  'abdullatif': array([-0.00028286, -0.00017922]),
#  'abdullayev': array([-0.00024346, -0.00016947]),
#  'abdullaziz': array([-0.00072742, -0.00063838]),
#  'abdulmuhsey': array([-5.48021399e-05, -4.38905399e-05]),
#  'abdulrah': array([-0.00033501, -0.00022526]),
#  'abdulvehab': array([-0.00030775, -0.00024418]),
#  'abdurezak': array([-0.00015387, -0.00012209]),
#  'abdurrah': array([-0.00028208, -0.00024882]),
#  'abdussalam': array([-0.00034722, -0.00030734]),
#  'abdías': array([-0.00259101, -0.00138098]),
#  'abdóy': array([-0.01839628, -0.00958826]),
#  'abe': array([-0.00401186, -0.00051812]),
#  'abeba': array([-0.00112669, -0.0008131 ]),
#  'abebe': array([-0.00099174, -0.00091288]),
#  'abecasis': array([-0.00037456, -0.00029934]),
#  'abecedario': array([-0.00018863, -0.00014404]),
#  'abecia': array([-2.61561396e-02, -4.57819891e-05]),
#  'abecé': array([-2.44951871e-07, -9.68782615e-08]),
#  'abedi': array([-0.00021661, -0.00018099]),
#  'abedrabbo': array([-0.00213135, -0.00086322]),
#  'abedul': array([-0.00053667, -0.00044929]),
#  'abeggii': array([-9.16714274e-05, -6.12309595e-05]),
#  'abeggley': array([-0.00028794, -0.00024226]),
#  'abeillei': array([-0.00391978, -0.00235886]),
#  'abeilles': array([-0.00019421, -0.0001529 ]),
#  'abeja': array([-0.00071149, -0.00038163]),
#  'abejachado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abejar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abejaruco': array([-6.12379677e-08, -2.42195654e-08]),
#  'abejas': array([-0.00022809, -0.00016636]),
#  'abejera': array([-1.22475935e-07, -4.84391307e-08]),
#  'abejo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abejorral': array([-1.49056262e-04, -3.69897237e-05]),
#  'abejorrear': array([-1.83713903e-07, -7.26586961e-08]),
#  'abejorro': array([-1.22475935e-07, -4.84391307e-08]),
#  'abejóy': array([-1.22475935e-07, -4.84391307e-08]),
#  'abel': array([-0.31135927,  0.81139854]),
#  'abela': array([-0.00065394, -0.00034933]),
#  'abelarda': array([-0.00019788, -0.00014784]),
#  'abelardo': array([-0.05103744, -0.02885959]),
#  'abelhammer': array([-6.53329736e-05, -6.34077549e-05]),
#  'abelii': array([-0.00148688, -0.00014957]),
#  'abelio': array([-0.00437972, -0.00270816]),
#  'abella': array([-0.00031472, -0.00012369]),
#  'abellaca': array([-6.12379677e-08, -2.42195654e-08]),
#  'abellacar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abellada': array([-0.00021377, -0.00017859]),
#  'abellotado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abeloki': array([-0.00018751, -0.00014582]),
#  'abelsoy': array([-9.21941609e-05, -7.47430364e-05]),
#  'abemoladamente': array([-6.12379677e-08, -2.42195654e-08]),
#  'abemolar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abenaki': array([-0.00063915, -0.00040587]),
#  'abenakipenobscot': array([-0.00025566, -0.00016235]),
#  'abenbury': array([-9.37361336e-05, -6.90524845e-05]),
#  'abencerraje': array([-0.0002876 , -0.00023449]),
#  'abencia': array([-0.00173274, -0.00089033]),
#  'abend': array([-0.00014177, -0.00012513]),
#  'abendaño': array([-0.001564 , -0.0009023]),
#  'abends': array([-3.73660151e-05, -3.18951751e-05]),
#  'abenjacáy': array([-6.52669466e-05, -4.40134875e-05]),
#  'abeno': array([-1.96225591e-04, -3.60869801e-05]),
#  'abenoku': array([-0.00040599, -0.0002664 ]),
#  'abensur': array([-0.00416343, -0.00260929]),
#  'abente': array([-0.00029966, -0.00012975]),
#  'abenteuer': array([-0.00012401, -0.00010623]),
#  'abenuz': array([-6.12379677e-08, -2.42195654e-08]),
#  'aber': array([-0.00021456, -0.00016222]),
#  'abera': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberaeroy': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberastaiy': array([-0.00037612, -0.00012337]),
#  'aberavoy': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberbythych': array([-9.37361336e-05, -6.90524845e-05]),
#  'abercary': array([-9.37361336e-05, -6.90524845e-05]),
#  'abercio': array([-0.00207163, -0.00130116]),
#  'abercrombie': array([-5.51474637e-05, -4.73303226e-05]),
#  'abercynoy': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberdare': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberdaroy': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberdeencitygovuk': array([-0.00022862, -0.00013215]),
#  'aberdeenshire': array([-0.00117906, -0.00079332]),
#  'aberdeey': array([-0.00676826, -0.00419772]),
#  'aberdovey': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberedw': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberenjenado': array([-1.22475935e-07, -4.84391307e-08]),
#  'aberfala': array([-0.00049185, -0.0002495 ]),
#  'aberffraw': array([-9.37361336e-05, -6.90524845e-05]),
#  'abergavenny': array([-9.37361336e-05, -6.90524845e-05]),
#  'abergele': array([-9.37361336e-05, -6.90524845e-05]),
#  'abergwili': array([-9.37361336e-05, -6.90524845e-05]),
#  'abergynolwyy': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberhafes': array([-9.37361336e-05, -6.90524845e-05]),
#  'abernant': array([-9.37361336e-05, -6.90524845e-05]),
#  'abernoy': array([-0.00021653, -0.00012175]),
#  'aberporth': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberra': array([-6.12379677e-08, -2.42195654e-08]),
#  'aberracióy': array([-3.47086499e-05, -2.51225313e-05]),
#  'aberrans': array([-0.00198169, -0.00197577]),
#  'aberranshardy': array([-0.00066056, -0.00065859]),
#  'aberrante': array([-6.12379677e-08, -2.42195654e-08]),
#  'aberrar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abersychay': array([-9.37361336e-05, -6.90524845e-05]),
#  'abertal': array([-1.22475935e-07, -4.84391307e-08]),
#  'abertawe': array([-0.00239683, -0.00111355]),
#  'abertillery': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberto': array([-5.91689829e-05, -4.58999134e-05]),
#  'abertura': array([-1.2419106e-06, -5.7043808e-07]),
#  'aberturas': array([-6.12379677e-08, -2.42195654e-08]),
#  'aberwheeler': array([-9.37361336e-05, -6.90524845e-05]),
#  'aberystwyth': array([-0.00019661, -0.00015414]),
#  'abestia': array([-6.12379677e-08, -2.42195654e-08]),
#  'abestiado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abestializado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abesé': array([-6.12379677e-08, -2.42195654e-08]),
#  'abesóy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abetal': array([-1.22475935e-07, -4.84391307e-08]),
#  'abetar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abete': array([-6.12379677e-08, -2.42195654e-08]),
#  'abetinote': array([-6.12379677e-08, -2.42195654e-08]),
#  'abetnum': array([-1.30332494e-04, -8.81935327e-05]),
#  'abeto': array([-0.00022291, -0.00020265]),
#  'abetunado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abey': array([-6.12379677e-08, -2.42195654e-08]),
#  'abe安倍': array([-1.51304053e-04, -9.50401886e-05]),
#  'abgeordnetenhaus': array([-6.30118665e-05, -5.41880372e-05]),
#  'abh': array([-9.10107541e-05, -7.21287403e-05]),
#  'abhandlung': array([-0.00013375, -0.00011832]),
#  'abhandlungey': array([-0.00022175, -0.00019043]),
#  'abhijit': array([-0.00027946, -0.00021652]),
#  'abhishek': array([-0.00019573, -0.00017995]),
#  'abhisit': array([-0.00144277, -0.00095926]),
#  'abhnum': array([-0.00054681, -0.00035542]),
#  'abhorsey': array([-0.00010194, -0.00010457]),
#  'abi': array([-0.00068691, -0.00054666]),
#  'abia': array([-0.00057689, -0.00039878]),
#  'abiah': array([-0.00032281, -0.00029615]),
#  'abiatar': array([-7.38736690e-07, -3.74494703e-07]),
#  'abiathar': array([-7.38736690e-07, -3.74494703e-07]),
#  'abiay': array([-0.00011344, -0.00011249]),
#  'abib': array([-0.00054785, -0.00046122]),
#  'abibatou': array([-0.00013113, -0.00010369]),
#  'abidal': array([-0.00165938, -0.00135789]),
#  'abidine': array([-0.00129974, -0.00098742]),
#  'abidjanaise': array([-0.0041471 , -0.00224275]),
#  'abidjay': array([-0.00110024, -0.00058197]),
#  'abidul': array([-6.12379677e-08, -2.42195654e-08]),
#  'abidúl': array([-6.12379677e-08, -2.42195654e-08]),
#  'abier': array([-0.00071434, -0.00054503]),
#  'abiertamente': array([-1.48148999e-06, -7.44454997e-07]),
#  'abiertapukyu': array([-7.36840279e-06, -6.19510350e-06]),
#  'abiertas': array([-0.00136618, -0.00090066]),
#  'abierto': array([-0.00358059, -0.00268463]),
#  'abiertos': array([-0.00015322, -0.00011556]),
#  'abies': array([-0.00307336, -0.00314341]),
#  'abietifolia': array([-6.61394413e-06, -9.16879518e-06]),
#  'abietino': array([-6.12379677e-08, -2.42195654e-08]),
#  'abietinum': array([-2.84688416e-05, -2.40584148e-05]),
#  'abietáceo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiga': array([-6.12379677e-08, -2.42195654e-08]),
#  'abigail': array([-0.00099677, -0.00083985]),
#  'abigarrado': array([-1.83713903e-07, -7.26586961e-08]),
#  'abigarramiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abigarrarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abigaíl': array([-1.14313824e-04, -8.87173726e-05]),
#  'abigeato': array([-2.91393641e-05, -1.97048508e-05]),
#  'abigeo': array([-7.55016399e-06, -5.03114772e-06]),
#  'abigotado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiha': array([-4.28665774e-07, -1.69536958e-07]),
#  'abihakunay': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiharuku': array([-6.12379677e-08, -2.42195654e-08]),
#  'abihay': array([-1.22475935e-07, -4.84391307e-08]),
#  'abildgaard': array([-0.00048515, -0.00032763]),
#  'abilene': array([-7.51106267e-05, -4.85549805e-05]),
#  'abilinia': array([-1.47747338e-06, -7.48989407e-07]),
#  'abilio': array([-0.00458439, -0.00306568]),
#  'abilities': array([-1.11206700e-04, -7.42247218e-05]),
#  'ability': array([-0.00018667, -0.00016265]),
#  'abilla': array([-6.12379677e-08, -2.42195654e-08]),
#  'abillana': array([-1.83713903e-07, -7.26586961e-08]),
#  'abillu': array([-0.00031758, -0.00022086]),
#  'abillunumnum': array([-0.00073891, -0.00068273]),
#  'abilsato': array([-0.00032022, -0.00010535]),
#  'abimael': array([-0.00886261, -0.00573067]),
#  'abina': array([-4.28665774e-07, -1.69536958e-07]),
#  'abinader': array([-0.00027522, -0.0001616 ]),
#  'abingdonii': array([-0.00074851,  0.00043445]),
#  'abingdoy': array([-0.00143759,  0.00084947]),
#  'abininakuy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abioduy': array([-1.43879968e-04, -9.37159077e-05]),
#  'abiogénesis': array([-6.12379677e-08, -2.42195654e-08]),
#  'abipoy': array([-9.46923584e-05, -7.44723002e-05]),
#  'abipuy': array([-9.46923584e-05, -7.44723002e-05]),
#  'abipóy': array([-9.46923584e-05, -7.44723002e-05]),
#  'abis': array([-1.83713903e-07, -7.26586961e-08]),
#  'abisa': array([-0.00014885, -0.00012213]),
#  'abisagrar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abisal': array([-1.22475935e-07, -4.84391307e-08]),
#  'abiseo': array([-0.18239627, -0.09815783]),
#  'abishira': array([-9.97689475e-05, -5.00128334e-05]),
#  'abisichi': array([-1.83713903e-07, -7.26586961e-08]),
#  'abisinia': array([-0.00103762, -0.00074545]),
#  'abisinio': array([-0.00035049, -0.00033454]),
#  'abismada': array([-6.12379677e-08, -2.42195654e-08]),
#  'abismado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abismal': array([-6.12379677e-08, -2.42195654e-08]),
#  'abismar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abismarse': array([-1.83713903e-07, -7.26586961e-08]),
#  'abismo': array([-0.00076938, -0.00063071]),
#  'abismos': array([-0.00048286, -0.00033775]),
#  'abismático': array([-6.12379677e-08, -2.42195654e-08]),
#  'abissinia': array([-0.00028628, -0.00025587]),
#  'abitagua': array([-0.00031674, -0.00016169]),
#  'abitaque': array([-6.12379677e-08, -2.42195654e-08]),
#  'abitibitémiscamingue': array([-1.81726742e-04, -8.42580599e-05]),
#  'abitu': array([-2.44951871e-07, -9.68782615e-08]),
#  'abitudine': array([-9.12430084e-05, -7.60625713e-05]),
#  'abituy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiud': array([-2.95494676e-06, -1.49797881e-06]),
#  'abiy': array([-0.00117152, -0.00084679]),
#  'abiyasiyuy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiyay': array([-0.0125474 , -0.00684345]),
#  'abiyu': array([-0.00037325, -0.00019936]),
#  'abiyunmi': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiyuy': array([-2.20456684e-06, -8.71904353e-07]),
#  'abiyáy': array([-0.00094786, -0.00033181]),
#  'abiyúy': array([-1.22475935e-07, -4.84391307e-08]),
#  'abizcochado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abiótico': array([-6.12379677e-08, -2.42195654e-08]),
#  'abjuracióy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abjurar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abkhazia': array([-1.48320939e-04, -3.32235612e-05]),
#  'abl': array([-7.65474596e-06, -3.02744567e-06]),
#  'abla': array([-1.03788727e-04, -7.16665147e-05]),
#  'ablacióy': array([-3.06189838e-07, -1.21097827e-07]),
#  'ablandabrevas': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablandado': array([-3.06189838e-07, -1.21097827e-07]),
#  'ablandador': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablandamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablandar': array([-7.34855612e-07, -2.90634784e-07]),
#  'ablandarse': array([-3.67427806e-07, -1.45317392e-07]),
#  'ablandativo': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablande': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablativo': array([-0.00046572, -0.00026071]),
#  'ablay': array([-1.83713903e-07, -7.26586961e-08]),
#  'ablaze': array([-0.00132531, -0.00103862]),
#  'able': array([-0.00082975, -0.00068204]),
#  'ablebey': array([-7.76682097e-05, -6.24281945e-05]),
#  'ablentar': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablepharus': array([-0.00192103, -0.00191502]),
#  'ablepharusbezzi': array([-0.00064034, -0.00063834]),
#  'ablf': array([-0.00018711, -0.00016521]),
#  'abluciones': array([-6.12379677e-08, -2.42195654e-08]),
#  'ablucióy': array([-3.06189838e-07, -1.21097827e-07]),
#  'ablusado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abnaki': array([-1.27829707e-04, -8.11744470e-05]),
#  'abne': array([-1.22475935e-07, -4.84391307e-08]),
#  'abnegación': array([-0.00052502, -0.00034068]),
#  'abnegacióy': array([-0.00052857, -0.00043549]),
#  'abnegado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abnegarse': array([-1.83713903e-07, -7.26586961e-08]),
#  'abner': array([-0.00074359, -0.00044138]),
#  'abnormis': array([-0.00110284, -0.00108967]),
#  'abnormishardy': array([-0.00036761, -0.00036322]),
#  'abnudi': array([-0.00026227, -0.00020739]),
#  'abnumabot': array([-0.00054681, -0.00035542]),
#  'abo': array([-1.26891589e-04, -9.96439586e-05]),
#  'aboard': array([-0.00021718, -0.0001862 ]),
#  'abobado': array([-2.44951871e-07, -9.68782615e-08]),
#  'abobamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abobarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abocado': array([-1.83713903e-07, -7.26586961e-08]),
#  'abocadonum': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocando': array([-1.22475935e-07, -4.84391307e-08]),
#  'abocar': array([-4.89903741e-07, -1.93756523e-07]),
#  'abocardado': array([-1.83713903e-07, -7.26586961e-08]),
#  'abocardar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocaríay': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocastro': array([-1.22475935e-07, -4.84391307e-08]),
#  'abocate': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocetado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocetar': array([-1.83713903e-07, -7.26586961e-08]),
#  'abochor': array([-6.12379677e-08, -2.42195654e-08]),
#  'abochornar': array([-2.44951871e-07, -9.68782615e-08]),
#  'abochornarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocicarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocinado': array([-1.83713903e-07, -7.26586961e-08]),
#  'abocinamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocinar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abocinarse': array([-2.44951871e-07, -9.68782615e-08]),
#  'abocines': array([-6.12379677e-08, -2.42195654e-08]),
#  'abofetea': array([-1.22475935e-07, -4.84391307e-08]),
#  'abofetear': array([-1.4746564e-05, -9.9223821e-06]),
#  'abofetearch': array([-7.53559315e-06, -5.10437393e-06]),
#  'abofetearinchi': array([-6.12379677e-08, -2.42195654e-08]),
#  'aboga': array([-6.12379677e-08, -2.42195654e-08]),
#  'abogacía': array([-6.12379677e-08, -2.42195654e-08]),
#  'abogada': array([-0.00044614, -0.00015038]),
#  'abogaderas': array([-6.12379677e-08, -2.42195654e-08]),
#  'abogadesca': array([-6.12379677e-08, -2.42195654e-08]),
#  'abogadesco': array([-6.12379677e-08, -2.42195654e-08]),
#  'abogadil': array([-6.12379677e-08, -2.42195654e-08]),
#  'abogado': array([-0.007502  , -0.00359434]),
#  'abogadoabogaduy': array([-1.50711863e-05, -1.02087479e-05]),
#  'abogadomanay': array([-1.50711863e-05, -1.02087479e-05]),
#  'abogados': array([-0.00016934, -0.00013559]),
#  'abogadu': array([-3.01423726e-05, -2.04174957e-05]),
#  'abogaduyqa': array([-7.53559315e-06, -5.10437393e-06]),
#  'abogamiento': array([-1.22475935e-07, -4.84391307e-08]),
#  'abogar': array([-2.44951871e-07, -9.68782615e-08]),
#  'aboid': array([-0.00133554, -0.00077042]),
#  'aboidwarmi': array([-0.00032873, -0.00027528]),
#  'abol': array([-6.12379677e-08, -2.42195654e-08]),
#  'abolengo': array([-3.06189838e-07, -1.21097827e-07]),
#  'abolfazl': array([-5.40748208e-05, -4.64197014e-05]),
#  'abolghasem': array([-2.70374104e-05, -2.32098507e-05]),
#  'abolicionis': array([-0.00015923, -0.00011808]),
#  'abolicionismo': array([-1.22475935e-07, -4.84391307e-08]),
#  'abolicióy': array([-0.00110107, -0.00063526]),
#  'abolir': array([-1.83713903e-07, -7.26586961e-08]),
#  'abolish': array([-0.00033284, -0.00030455]),
#  'abolished': array([-1.04210318e-04, -5.41434560e-05]),
#  'abolkheir': array([-5.40748208e-05, -4.64197014e-05]),
#  'abollado': array([-4.28665774e-07, -1.69536958e-07]),
#  'abolladura': array([-1.22475935e-07, -4.84391307e-08]),
#  'abollar': array([-4.89903741e-07, -1.93756523e-07]),
#  'abollarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abollonar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abolorio': array([-6.12379677e-08, -2.42195654e-08]),
#  'abolsado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abolsarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abomanona': array([-0.00014775, -0.00011669]),
#  'abomaso': array([-1.22475935e-07, -4.84391307e-08]),
#  'abomba': array([-6.12379677e-08, -2.42195654e-08]),
#  'abombado': array([-2.44951871e-07, -9.68782615e-08]),
#  'abombados': array([-6.12379677e-08, -2.42195654e-08]),
#  'abombamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abombando': array([-6.12379677e-08, -2.42195654e-08]),
#  'abombar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abombarse': array([-3.67427806e-07, -1.45317392e-07]),
#  'abominable': array([-0.00016472, -0.00015675]),
#  'abominacióy': array([-2.31067597e-06, -1.15166083e-06]),
#  'abominar': array([-3.67427806e-07, -1.45317392e-07]),
#  'abona': array([-1.62001551e-04, -8.17481726e-05]),
#  'abonada': array([-1.22475935e-07, -4.84391307e-08]),
#  'abonado': array([-4.89903741e-07, -1.93756523e-07]),
#  'abonador': array([-1.83713903e-07, -7.26586961e-08]),
#  'abonamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abonanzar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abonar': array([-7.34855612e-07, -2.90634784e-07]),
#  'abonarse': array([-1.83713903e-07, -7.26586961e-08]),
#  'abonaré': array([-6.12379677e-08, -2.42195654e-08]),
#  'abonera': array([-4.07616575e-04, -5.74000586e-05]),
#  'abonizio': array([-0.00023967, -0.00020953]),
#  'abono': array([-0.00037017, -0.00018571]),
#  'abony': array([-8.79720842e-05, -7.55684179e-05]),
#  'aboqui': array([-6.12379677e-08, -2.42195654e-08]),
#  'aboquillar': array([-1.83713903e-07, -7.26586961e-08]),
#  'abor': array([-8.29185984e-07, -4.07205837e-07]),
#  'abora': array([-0.00271432,  0.00462141]),
#  'aboral': array([-6.12379677e-08, -2.42195654e-08]),
#  'abord': array([-0.00017452, -0.0001358 ]),
#  'abordable': array([-6.12379677e-08, -2.42195654e-08]),
#  'abordado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abordador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abordados': array([-6.12379677e-08, -2.42195654e-08]),
#  'abordaje': array([-1.83713903e-07, -7.26586961e-08]),
#  'abordajes': array([-0.000156  , -0.00012635]),
#  'abordar': array([-2.22575311e-05, -1.40025506e-05]),
#  'abordarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborday': array([-2.20437239e-05, -1.39179901e-05]),
#  'abordó': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborigeneus': array([-2.76272013e-04,  3.54705199e-05]),
#  'aborigey': array([-0.00095374, -0.00060735]),
#  'aboriginal': array([-0.00014442, -0.00012477]),
#  'aborigènes': array([-8.94741957e-05, -5.61471581e-05]),
#  'abormiridafla': array([-7.85586056e-05, -3.85211653e-05]),
#  'aborracha': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborrajarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborrascar': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborre': array([-1.47747338e-06, -7.48989407e-07]),
#  'aborrece': array([-5.74907798e-06, -2.90786331e-06]),
#  'aborrecedor': array([-1.22475935e-07, -4.84391307e-08]),
#  'aborrecer': array([-6.73617644e-07, -2.66415219e-07]),
#  'aborreceráy': array([-7.38736690e-07, -3.74494703e-07]),
#  'aborrecey': array([-2.19275465e-06, -1.10502305e-06]),
#  'aborrecible': array([-2.44951871e-07, -9.68782615e-08]),
#  'aborrecido': array([-4.55694302e-05, -2.72988700e-05]),
#  'aborrecidos': array([-2.95494676e-06, -1.49797881e-06]),
#  'aborrecieroy': array([-1.47747338e-06, -7.48989407e-07]),
#  'aborrecimiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborreció': array([-1.47747338e-06, -7.48989407e-07]),
#  'aborrecíay': array([-7.38736690e-07, -3.74494703e-07]),
#  'aborregado': array([-1.22475935e-07, -4.84391307e-08]),
#  'aborregarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'aborricado': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborricar': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborricarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abortado': array([-1.83713903e-07, -7.26586961e-08]),
#  'abortamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abortar': array([-5.95895608e-05, -1.56227960e-05]),
#  'abortarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abortero': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborti': array([-6.12379677e-08, -2.42195654e-08]),
#  'abortio': array([-0.00018943, -0.00012297]),
#  'abortioy': array([-1.20830942e-04, -7.10177372e-05]),
#  'abortis': array([-6.12379677e-08, -2.42195654e-08]),
#  'abortivo': array([-1.83713903e-07, -7.26586961e-08]),
#  'aborto': array([-0.00029717, -0.00013666]),
#  'abortos': array([-0.15862011, -0.07699614]),
#  'abortus': array([-0.00181743, -0.00104041]),
#  'abortóy': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborujar': array([-6.12379677e-08, -2.42195654e-08]),
#  'aborígen': array([-0.00038149, -0.00025444]),
#  'aborígenes': array([-0.00253977, -0.0013208 ]),
#  'abotagado': array([-2.44951871e-07, -9.68782615e-08]),
#  'abotagamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abotagamiey': array([-6.12379677e-08, -2.42195654e-08]),
#  'abotagarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abotijado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abotinadonumnumnum': array([-6.12379677e-08, -2.42195654e-08]),
#  'abotonador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abotonadura': array([-6.12379677e-08, -2.42195654e-08]),
#  'abotonar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abott': array([-0.00017654, -0.00015133]),
#  'abottabad': array([-2.47156176e-05, -2.59336980e-05]),
#  'aboubacar': array([-0.00023158, -0.00017656]),
#  'aboul': array([-0.00013992, -0.00011358]),
#  'about': array([-0.01272383, -0.00838247]),
#  'aboutespanol': array([-0.000184  , -0.00011162]),
#  'abova': array([-2.78354168e-05,  1.16050886e-05]),
#  'above': array([-0.00175542, -0.00128888]),
#  'abovedada': array([-6.12379677e-08, -2.42195654e-08]),
#  'abovedado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abovedando': array([-6.12379677e-08, -2.42195654e-08]),
#  'abovedar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abowjay': array([-0.00115914, -0.00090814]),
#  'aboyans': array([-1.15400898e-04, -6.83042149e-05]),
#  'aboyar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abpatma': array([-0.00082997,  0.00041674]),
#  'abr': array([-8.65262906e-05, -6.82402947e-05]),
#  'abra': array([-0.00595588, -0.0037688 ]),
#  'abrabam': array([-7.38736690e-07, -3.74494703e-07]),
#  'abracadabra': array([-6.12379677e-08, -2.42195654e-08]),
#  'abracadabrante': array([-1.22475935e-07, -4.84391307e-08]),
#  'abracar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrady': array([-4.4506195e-06, -5.2277417e-06]),
#  'abraha': array([-0.00029894, -0.00025676]),
#  'abraham': array([-0.0210398 , -0.00852981]),
#  'abrahamhuay': array([-7.38736690e-07, -3.74494703e-07]),
#  'abrahamiay': array([-0.00018361, -0.00015142]),
#  'abrahamlorentzdirac': array([-5.30372936e-05, -4.76198609e-05]),
#  'abrahay': array([-0.0006984 , -0.00045565]),
#  'abrajam': array([-3.98935161e-06, -7.10398883e-07]),
#  'abram': array([-0.00504218, -0.00417698]),
#  'abramis': array([-0.00021527, -0.00018331]),
#  'abramo': array([-0.00027509, -0.00015633]),
#  'abramovich': array([-1.48714225e-04, -5.01261059e-05]),
#  'abramowitz': array([-0.0001745 , -0.00017032]),
#  'abrams': array([-0.00056771, -0.00046774]),
#  'abramsjustice': array([-0.00023407, -0.00016504]),
#  'abramsoy': array([-0.00161785, -0.00139578]),
#  'abrantes': array([-0.00076965, -0.00024487]),
#  'abras': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrasa': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrasada': array([-4.72682748e-05, -2.83290473e-05]),
#  'abrasador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrasamiento': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrasar': array([-2.44951871e-07, -9.68782615e-08]),
#  'abrasarse': array([-3.06189838e-07, -1.21097827e-07]),
#  'abrasiva': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrasivo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrasióy': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrasándose': array([-6.12379677e-08, -2.42195654e-08]),
#  'abraxas': array([-0.00012633, -0.00010301]),
#  'abraza': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrazadera': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrazaderas': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrazado': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrazamiento': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrazamos': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrazar': array([-0.00018414, -0.00014778]),
#  'abrazareis': array([-7.38736690e-07, -3.74494703e-07]),
#  'abrazaroy': array([-7.38736690e-07, -3.74494703e-07]),
#  'abrazarse': array([-3.67427806e-07, -1.45317392e-07]),
#  'abrazarte': array([-7.53932075e-05, -4.34086689e-05]),
#  'abrazay': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrazo': array([-0.00032198, -0.00025853]),
#  'abrazos': array([-0.00018935, -0.00016268]),
#  'abrazándolo': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrazó': array([-1.83713903e-07, -7.26586961e-08]),
#  'abraão': array([-4.27862016e-05, -3.12208616e-05]),
#  'abraçaço': array([-3.94115576e-05, -3.32390926e-05]),
#  'abre': array([-0.00066043, -0.00049315]),
#  'abreae': array([-0.00046537, -0.00030278]),
#  'abreboca': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrebotellas': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrecartas': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrecht': array([-0.00072668, -0.00032341]),
#  'abreganas': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrego': array([-0.00054728, -0.00016948]),
#  'abregu': array([-0.00121586, -0.00072039]),
#  'abregó': array([-0.00032772, -0.0002597 ]),
#  'abrelatas': array([-1.22475935e-07, -4.84391307e-08]),
#  'abreme': array([-2.00973449e-05, -1.22270279e-05]),
#  'abrepuño': array([-6.12379677e-08, -2.42195654e-08]),
#  'abres': array([-6.12379677e-08, -2.42195654e-08]),
#  'abreu': array([-0.00185281, -0.00119936]),
#  'abreus': array([-0.00047028, -0.00028494]),
#  'abreva': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrevadero': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrevado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrevador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrevar': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrevarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrevia': array([-3.06189838e-07, -1.21097827e-07]),
#  'abreviaciones': array([-7.38736690e-07, -3.74494703e-07]),
#  'abreviacióy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abreviada': array([-1.22475935e-07, -4.84391307e-08]),
#  'abreviado': array([-8.29185984e-07, -4.07205837e-07]),
#  'abreviador': array([-1.22475935e-07, -4.84391307e-08]),
#  'abreviar': array([-2.44951871e-07, -9.68782615e-08]),
#  'abreviatura': array([-0.00053382, -0.00025404]),
#  'abreviaturas': array([-6.73617644e-07, -2.66415219e-07]),
#  'abrevió': array([-7.38736690e-07, -3.74494703e-07]),
#  'abrey': array([-0.00211568, -0.00138661]),
#  'abri': array([-5.51141709e-07, -2.17976088e-07]),
#  'abriaquí': array([-1.49056262e-04, -3.69897237e-05]),
#  'abribonando': array([-6.12379677e-08, -2.42195654e-08]),
#  'abribonarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abridero': array([-1.83713903e-07, -7.26586961e-08]),
#  'abridor': array([-3.06189838e-07, -1.21097827e-07]),
#  'abridúr': array([-6.12379677e-08, -2.42195654e-08]),
#  'abriendo': array([-0.00079548, -0.0006502 ]),
#  'abriera': array([-6.12379677e-08, -2.42195654e-08]),
#  'abriere': array([-7.38736690e-07, -3.74494703e-07]),
#  'abriese': array([-7.38736690e-07, -3.74494703e-07]),
#  'abriga': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigadora': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigadura': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigamiey': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigar': array([-6.73617644e-07, -2.66415219e-07]),
#  'abrigarme': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigaros': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrigarse': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrigaño': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrightfrac': array([-0.00136348, -0.00072832]),
#  'abrigo': array([-0.00167186, -0.00097643]),
#  'abrigu': array([-2.44951871e-07, -9.68782615e-08]),
#  'abriguyuy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrikosov': array([-1.80243856e-05, -1.32082082e-05]),
#  'abril': array([-0.02240443, -0.01226569]),
#  'abriles': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrileño': array([-6.12379677e-08, -2.42195654e-08]),
#  'abriljunio': array([-0.00028777, -0.00022852]),
#  'abrillantador': array([-1.22475935e-07, -4.84391307e-08]),
#  'abrillantar': array([-2.44951871e-07, -9.68782615e-08]),
#  'abrilseptiembre': array([-1.41623115e-04, -9.97931512e-05]),
#  'abrilwarmi': array([-0.00054075, -0.00021703]),
#  'abrimiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrimos': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrir': array([-0.00018903, -0.00013583]),
#  'abriremos': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrirla': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrirle': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrirme': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrirse': array([-1.77255654e-06, -7.80308108e-07]),
#  'abrirá': array([-4.52701627e-05, -2.84474582e-05]),
#  'abrirás': array([-6.12379677e-08, -2.42195654e-08]),
#  'abriré': array([-8.29185984e-07, -4.07205837e-07]),
#  'abriéronse': array([-7.38736690e-07, -3.74494703e-07]),
#  'abrió': array([-9.01421839e-05, -6.17576671e-05]),
#  'abrnumnum': array([-1.13138764e-05, -1.17719325e-05]),
#  'abro': array([-8.29185984e-07, -4.07205837e-07]),
#  'abroad': array([-0.00017999, -0.00015845]),
#  'abrocha': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrochador': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrochadura': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrochamiento': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrochar': array([-1.83713903e-07, -7.26586961e-08]),
#  'abrocharse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrody': array([-4.4506195e-06, -5.2277417e-06]),
#  'abrogacióy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrogadas': array([-1.26803417e-04, -3.31644534e-05]),
#  'abrogar': array([-7.70225324e-07, -3.83886945e-07]),
#  'abrojo': array([-0.00035377, -0.00021694]),
#  'abrojos': array([-6.38126992e-05, -3.75167576e-05]),
#  'abroncado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abroncar': array([-2.44951871e-07, -9.68782615e-08]),
#  'abroque': array([-6.12379677e-08, -2.42195654e-08]),
#  'abroquelado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abroquelar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abroquelarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrotoñar': array([-6.12379677e-08, -2.42195654e-08]),
#  'abroy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abru': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrumador': array([-1.83713903e-07, -7.26586961e-08]),
#  'abrumar': array([-7.56607305e-06, -6.15127209e-06]),
#  'abrumarse': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrumarsenum': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrupcióy': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrupto': array([-4.89903741e-07, -1.93756523e-07]),
#  'abrus': array([-0.00142989, -0.00126881]),
#  'abrutado': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrutanu': array([-6.12379677e-08, -2.42195654e-08]),
#  'abruzaremos': array([-6.12379677e-08, -2.42195654e-08]),
#  'abruzarse': array([-2.44951871e-07, -9.68782615e-08]),
#  'abruzos': array([-0.00055415, -0.00025531]),
#  'abruzzi': array([-0.00039129, -0.00033291]),
#  'abruzzo': array([-0.00451227, -0.00227841]),
#  'abrázame': array([-0.00096274, -0.00071308]),
#  'abría': array([-7.38736690e-07, -3.74494703e-07]),
#  'abrígate': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrírsele': array([-1.22475935e-07, -4.84391307e-08]),
#  'abróchate': array([-6.12379677e-08, -2.42195654e-08]),
#  'abróchatelos': array([-6.12379677e-08, -2.42195654e-08]),
#  'abróchense': array([-6.12379677e-08, -2.42195654e-08]),
#  'abrótano': array([-6.12379677e-08, -2.42195654e-08]),
#  'abs': array([-0.00025229, -0.00019145]),
#  'absa': array([-0.00013113, -0.00010369]),
#  'absalom': array([-0.00021718, -0.0001862 ]),
#  'absaloy': array([-0.00047692, -0.00028209]),
#  'absalóy': array([-0.00025461, -0.00020655]),
#  'absaroka': array([-0.00015611, -0.00011219]),
#  'abscbnnewscom': array([-4.42538792e-05, -3.65887133e-05]),
#  'absceso': array([-6.06729664e-04, -5.75164223e-05]),
#  'abschließende': array([-3.40493042e-05, -2.96205703e-05]),
#  'absci': array([-6.12379677e-08, -2.42195654e-08]),
#  'abscisa': array([-8.02248599e-05, -4.18086189e-05]),
#  'abscondi': array([-0.00105086, -0.00103992]),
#  'absconditadrew': array([-0.00035029, -0.00034664]),
#  'absence': array([-0.00073112, -0.00060719]),
#  'absengamma': array([-0.00054681, -0.00035542]),
#  'absent': array([-5.82596124e-05, -4.74869430e-05]),
#  'absentis': array([-1.83713903e-07, -7.26586961e-08]),
#  ...}
